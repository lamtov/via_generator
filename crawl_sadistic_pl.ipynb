# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np 

req = requests.get('https://www.sadistic.pl/uzytkownicy/3', verify=False)
req.encoding = 'utf-8'
soup = BeautifulSoup(req.text, 'lxml')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sadistic.pl'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
def find_eps_td(tag):
    return tag.name=='td' and (len(tag.contents)>0 and  tag.contents[0].name=='span'  and tag.contents[0].contents[0].name=='a'
                             and 'name' in td_has_string[0].contents[0].contents[0]['class']  )
td_has_string=soup.find_all(find_eps_td)
td_has_string[0].contents[0].contents[0].text.replace(" ", "")

list_name=[td.contents[0].contents[0].text.replace(" ", "") for td in td_has_string]
list_name
# Out:
# ['pemmo22\xa0',
#  'blablabla\xa0',
#  'Adiz\xa0',
#  'KentuckyLife\xa0',
#  'plasta\xa0',
#  'Stawa\xa0',
#  'silia\xa0',
#  'Sklasyk\xa0',
#  'grippen\xa0',
#  'furcok\xa0',
#  'marcosmark\xa0',
#  'karraska\xa0',
#  'Vienio007\xa0',
#  'Drakkon\xa0',
#  'andyq\xa0',
#  'targacz88\xa0',
#  'joh2ny\xa0',
#  'pyzolekkk\xa0',
#  'TrawNick\xa0',
#  'Spanky\xa0',
#  'miszczus1989\xa0',
#  'BaronMatek\xa0',
#  'ValuasZorthun\xa0',
#  'm4dm3n\xa0',
#  'Kasimiec\xa0']

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np 
import os
from threading import Lock
from concurrent.futures import ThreadPoolExecutor

cur_dir = os.getcwd()

def find_td(tag):
    return tag.name=='td' and (len(tag.contents)>0 and  tag.contents[0].name=='span'  and tag.contents[0].contents[0].name=='a'
                             and 'name' in td_has_string[0].contents[0].contents[0]['class']  )


def write_list_name_sadistic_pl(count_page):
    global output
    try:
        req = requests.get('https://www.sadistic.pl/uzytkownicy/'+str(count_page), verify=False)
        req.encoding = 'utf-8'
        soup = BeautifulSoup(req.text, 'lxml')
        td_has_string=soup.find_all(find_td)
        list_name=[td.contents[0].contents[0].text.replace(" ", "") for td in td_has_string]
        for line in list_name:
            output.writelines(line+'\n')
    except Exception as e:
        print(str(e))
if __name__ == "__main__":
    stop = False
    tag='sadistic'
    if not os.path.exists(cur_dir+'/write_list_name_sadistic_pl'):
        os.makedirs(cur_dir+'/write_list_name_sadistic_pl')
    output = open(cur_dir+'/write_list_name_sadistic_pl/' +'output_'+str(tag)+'.txt', 'w', encoding='utf-8' )
    cur_count=0
    for count_page in range(1,8344):
        if count_page>cur_count+100:
            print(count_page)
            cur_count=count_page
        write_list_name_sadistic_pl( count_page)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sadistic.pl'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sadistic.pl'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.sadistic.pl'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...
